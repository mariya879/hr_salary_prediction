# %%
import numpy as np

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# # Exploratory Data Analysis and preprocessing

# %%
# loading the data from csv file to Pandas DataFrame
data = pd.read_csv('salarydata.csv')

# %%
data
# Out:
#        age         workclass   education  education-num      marital-status  \
# 0       39         State-gov   Bachelors             13       Never-married
# 1       50  Self-emp-not-inc   Bachelors             13  Married-civ-spouse
# 2       38           Private     HS-grad              9            Divorced
# 3       53           Private        11th              7  Married-civ-spouse
# 4       28           Private   Bachelors             13  Married-civ-spouse
# ...    ...               ...         ...            ...                 ...
# 32556   27           Private  Assoc-acdm             12  Married-civ-spouse
# 32557   40           Private     HS-grad              9  Married-civ-spouse
# 32558   58           Private     HS-grad              9             Widowed
# 32559   22           Private     HS-grad              9       Never-married
# 32560   52      Self-emp-inc     HS-grad              9  Married-civ-spouse
#
#               occupation   relationship   race     sex  capital-gain  \
# 0           Adm-clerical  Not-in-family  White    Male          2174
# 1        Exec-managerial        Husband  White    Male             0
# 2      Handlers-cleaners  Not-in-family  White    Male             0
# 3      Handlers-cleaners        Husband  Black    Male             0
# 4         Prof-specialty           Wife  Black  Female             0
# ...                  ...            ...    ...     ...           ...
# 32556       Tech-support           Wife  White  Female             0
# 32557  Machine-op-inspct        Husband  White    Male             0
# 32558       Adm-clerical      Unmarried  White  Female             0
# 32559       Adm-clerical      Own-child  White    Male             0
# 32560    Exec-managerial           Wife  White  Female         15024
#
#        capital-loss  hours-per-week native-country salary
# 0                 0              40  United-States  <=50K
# 1                 0              13  United-States  <=50K
# 2                 0              40  United-States  <=50K
# 3                 0              40  United-States  <=50K
# 4                 0              40           Cuba  <=50K
# ...             ...             ...            ...    ...
# 32556             0              38  United-States  <=50K
# 32557             0              40  United-States   >50K
# 32558             0              40  United-States  <=50K
# 32559             0              20  United-States  <=50K
# 32560             0              40  United-States   >50K
#
# [32561 rows x 14 columns]

# %%
data.tail(50)
# Out:
#        age         workclass     education  education-num      marital-status  \
# 32511   25         Local-gov     Bachelors             13       Never-married
# 32512   20           Private       HS-grad              9       Never-married
# 32513   46           Private       Masters             14  Married-civ-spouse
# 32514   40           Private     Assoc-voc             11  Married-civ-spouse
# 32515   66       Federal-gov          10th              6  Married-civ-spouse
# 32516   30           Private     Assoc-voc             11            Divorced
# 32517   36           Private       7th-8th              4  Married-civ-spouse
# 32518   57         Local-gov       HS-grad              9  Married-civ-spouse
# 32519   46           Private  Some-college             10  Married-civ-spouse
# 32520   27           Private       HS-grad              9       Never-married
# 32521   33           Private       HS-grad              9  Married-civ-spouse
# 32522   58           Private          11th              7  Married-civ-spouse
# 32523   30           Private       HS-grad              9            Divorced
# 32524   26           Private    Assoc-acdm             12       Never-married
# 32525   81                 ?     Assoc-voc             11            Divorced
# 32526   32           Private          10th              6  Married-civ-spouse
# 32527   22           Private  Some-college             10       Never-married
# 32528   31           Private       HS-grad              9  Married-civ-spouse
# 32529   29           Private       HS-grad              9           Separated
# 32530   35                 ?     Bachelors             13  Married-civ-spouse
# 32531   30                 ?     Bachelors             13       Never-married
# 32532   34           Private     Doctorate             16  Married-civ-spouse
# 32533   54           Private     Bachelors             13  Married-civ-spouse
# 32534   37           Private  Some-college             10            Divorced
# 32535   22           Private          12th              8       Never-married
# 32536   34           Private     Bachelors             13       Never-married
# 32537   30           Private       HS-grad              9       Never-married
# 32538   38           Private     Bachelors             13            Divorced
# 32539   71                 ?     Doctorate             16  Married-civ-spouse
# 32540   45         State-gov       HS-grad              9           Separated
# 32541   41                 ?       HS-grad              9           Separated
# 32542   72                 ?       HS-grad              9  Married-civ-spouse
# 32543   45         Local-gov    Assoc-acdm             12            Divorced
# 32544   31           Private       Masters             14            Divorced
# 32545   39         Local-gov    Assoc-acdm             12  Married-civ-spouse
# 32546   37           Private    Assoc-acdm             12            Divorced
# 32547   43           Private       HS-grad              9  Married-civ-spouse
# 32548   65  Self-emp-not-inc   Prof-school             15       Never-married
# 32549   43         State-gov  Some-college             10            Divorced
# 32550   43  Self-emp-not-inc  Some-college             10  Married-civ-spouse
# 32551   32           Private          10th              6  Married-civ-spouse
# 32552   43           Private     Assoc-voc             11  Married-civ-spouse
# 32553   32           Private       Masters             14       Never-married
# 32554   53           Private       Masters             14  Married-civ-spouse
# 32555   22           Private  Some-college             10       Never-married
# 32556   27           Private    Assoc-acdm             12  Married-civ-spouse
# 32557   40           Private       HS-grad              9  Married-civ-spouse
# 32558   58           Private       HS-grad              9             Widowed
# 32559   22           Private       HS-grad              9       Never-married
# 32560   52      Self-emp-inc       HS-grad              9  Married-civ-spouse
#
#               occupation    relationship                race     sex  \
#
# 32527             0             0              40  United-States  <=50K
# 32528             0             0              40  United-States  <=50K
# 32529             0             0              35  United-States  <=50K
# 32530             0             0              55  United-States   >50K
# 32531             0             0              99  United-States  <=50K
# 32532             0             0              60  United-States   >50K
# 32533             0             0              50          Japan   >50K
# 32534             0             0              39  United-States  <=50K
# 32535             0             0              35  United-States  <=50K
# 32536             0             0              55  United-States   >50K
# 32537             0             0              46  United-States  <=50K
# 32538         15020             0              45  United-States   >50K
# 32539             0             0              10  United-States   >50K
# 32540             0             0              40  United-States  <=50K
# 32541             0             0              32  United-States  <=50K
# 32542             0             0              25  United-States  <=50K
# 32543             0             0              48  United-States  <=50K
# 32544             0             0              30  United-States  <=50K
# 32545             0             0              20  United-States   >50K
# 32546             0             0              40  United-States  <=50K
# 32547             0             0              40         Mexico  <=50K
# 32548          1086             0              60  United-States  <=50K
# 32549             0             0              40  United-States  <=50K
# 32550             0             0              50  United-States  <=50K
# 32551             0             0              40  United-States  <=50K
# 32552             0             0              45  United-States  <=50K
# 32553             0             0              11         Taiwan  <=50K
# 32554             0             0              40  United-States   >50K
# 32555             0             0              40  United-States  <=50K
# 32556             0             0              38  United-States  <=50K
# 32557             0             0              40  United-States   >50K
# 32558             0             0              40  United-States  <=50K
# 32559             0             0              20  United-States  <=50K
# 32560         15024             0              40  United-States   >50K

# %%
data.shape
# Out:
# (32561, 14)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   education       32561 non-null  object
#  3   education-num   32561 non-null  int64
#  4   marital-status  32561 non-null  object
#  5   occupation      32561 non-null  object
#  6   relationship    32561 non-null  object
#  7   race            32561 non-null  object
#  8   sex             32561 non-null  object
#  9   capital-gain    32561 non-null  int64
#  10  capital-loss    32561 non-null  int64
#  11  hours-per-week  32561 non-null  int64
#  12  native-country  32561 non-null  object
#  13  salary          32561 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 3.5+ MB

# %%
data[data == '?'] = np.nan

# %%
data.isnull().sum()
# Out:
# age                  0
# workclass         1836
# education            0
# education-num        0
# marital-status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country     583
# salary               0
# dtype: int64

# %%
#filling of missing values created by using mode

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'education', 'education-num', 'marital-status',
#        'occupation', 'relationship', 'race', 'sex', 'capital-gain',
#        'capital-loss', 'hours-per-week', 'native-country', 'salary'],
#       dtype='object')

# %%
for col in ['workclass', 'occupation', 'native-country']:
    data[col].fillna(data[col].mode()[0], inplace=True)

# %%
data.isnull().sum()
# Out:
# age               0
# workclass         0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# salary            0
# dtype: int64

# %%
#data.duplicated().sum()

# %%
#data.drop_duplicates(keep=False, inplace=True)

# %%
#data.duplicated().sum()

# %% [markdown]
# # Data Visualization

# %% [markdown]
# # 2.1: Univariate Analysis

# %%
# Creating a distribution plot for 'Age'
age = data['age'].value_counts()

plt.figure(figsize=(8, 4))
#plt.style.use('fivethirtyeight')
sns.distplot(data['age'], bins=20)
plt.title('Distribution of Age', fontdict={
          'fontname': 'Monospace', 'fontsize': 20, 'fontweight': 'bold'})
plt.xlabel('Age', fontdict={'fontname': 'Monospace', 'fontsize': 15})
plt.ylabel('Number of people', fontdict={
           'fontname': 'Monospace', 'fontsize': 15})
plt.tick_params(labelsize=10)
plt.show()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(12,4))
sns.countplot(x='workclass', hue='salary', data=data)
plt.show()

# %% [markdown]
# 1. In every  sector the salary of majority is less than 50k except Self-emp-inc workclass .In the private sector the employees having the salary above 50k and below 50k have more gap .There is some working class with is unknown we can drop that rows later on .

# %%
data['workclass'].value_counts()
# Out:
# Private             24532
# Self-emp-not-inc     2541
# Local-gov            2093
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %% [markdown]
# On analysing the data,we get the below findings
#
# 1.Majority of those who completed the masters,Doctrate ,Pro-school have a salary greater than 50k .

# %%
# Creating a barplot for 'Education'
edu = data['education'].value_counts()

plt.style.use('seaborn')
plt.figure(figsize=(10, 5))
sns.barplot(edu.values, edu.index, palette='Paired')
plt.title('Distribution of Education', fontdict={
          'fontname': 'Monospace', 'fontsize': 20, 'fontweight': 'bold'})
plt.xlabel('Number of people', fontdict={
           'fontname': 'Monospace', 'fontsize': 15})
plt.ylabel('Education', fontdict={'fontname': 'Monospace', 'fontsize': 15})
plt.tick_params(labelsize=12)
plt.show()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
data['education'].value_counts()
# Out:
# HS-grad         10501
# Some-college     7291
# Bachelors        5355
# Masters          1723
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           646
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           333
# 1st-4th           168
# Preschool          51
# Name: education, dtype: int64

# %%
marital = data['marital-status'].value_counts()

plt.style.use('default')
plt.figure(figsize=(10, 7))
plt.pie(marital.values, labels=marital.index, startangle=10, explode=(
    0, 0.20, 0, 0, 0, 0, 0), shadow=True, autopct='%1.1f%%')
plt.title('Marital distribution', fontdict={
          'fontname': 'Monospace', 'fontsize': 20, 'fontweight': 'bold'})
plt.legend()
plt.legend(prop={'size': 7})
plt.axis('equal')
plt.show()

# %%
data['marital-status'].value_counts()
# Out:
# Married-civ-spouse       14976
# Never-married            10683
# Divorced                  4443
# Separated                 1025
# Widowed                    993
# Married-spouse-absent      418
# Married-AF-spouse           23
# Name: marital-status, dtype: int64

# %%
plt.figure(figsize=(20,4))
sns.countplot(x='occupation', hue='salary', data=data)
plt.show()

# %%
data['occupation'].value_counts()
# Out:
# Prof-specialty       5983
# Craft-repair         4099
# Exec-managerial      4066
# Adm-clerical         3770
# Sales                3650
# Other-service        3295
# Machine-op-inspct    2002
# Transport-moving     1597
# Handlers-cleaners    1370
# Farming-fishing       994
# Tech-support          928
# Protective-serv       649
# Priv-house-serv       149
# Armed-Forces            9
# Name: occupation, dtype: int64

# %%
data['relationship'].value_counts()
# Out:
# Husband           13193
# Not-in-family      8305
# Own-child          5068
# Unmarried          3446
# Wife               1568
# Other-relative      981
# Name: relationship, dtype: int64

# %%
# Creating a donut chart for 'Age'
relation = data['relationship'].value_counts()

plt.style.use('bmh')
plt.figure(figsize=(20, 10))
plt.pie(relation.values, labels=relation.index,
        startangle=50, autopct='%1.1f%%')
centre_circle = plt.Circle((0, 0), 0.7, fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
plt.title('Relationship distribution', fontdict={
          'fontname': 'Monospace', 'fontsize': 30, 'fontweight': 'bold'})
plt.axis('equal')
plt.legend(prop={'size': 15})
plt.show()

# %%
data['race'].value_counts()
# Out:
# White                 27816
# Black                  3124
# Asian-Pac-Islander     1039
# Amer-Indian-Eskimo      311
# Other                   271
# Name: race, dtype: int64

# %%
pip install squarify
# Out:
# Requirement already satisfied: squarify in c:\users\hp\anaconda3\lib\site-packages (0.4.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Creating a Treemap for 'Race'
import squarify
race = data['race'].value_counts()

plt.style.use('default')
plt.figure(figsize=(7, 5))
squarify.plot(sizes=race.values, label=race.index, value=race.values)
plt.title('Race distribution', fontdict={
          'fontname': 'Monospace', 'fontsize': 20, 'fontweight': 'bold'})
plt.show()

# %%
plt.figure(figsize=(6,3))
sns.countplot(x='sex', hue='salary', data=data)
plt.style.use('seaborn-whitegrid')
plt.figure(figsize=(7, 5))
plt.show()

# %%
data['sex'].value_counts()
# Out:
# Male      21790
# Female    10771
# Name: sex, dtype: int64

# %%
# Creating a barplot for 'Income'
income = data['salary'].value_counts()

plt.style.use('seaborn-whitegrid')
plt.figure(figsize=(6, 5))
sns.barplot(income.index, income.values, palette='bright')
plt.title('Distribution of Income', fontdict={
          'fontname': 'Monospace', 'fontsize': 20, 'fontweight': 'bold'})
plt.xlabel('Income', fontdict={'fontname': 'Monospace', 'fontsize': 15})
plt.ylabel('Number of people', fontdict={
           'fontname': 'Monospace', 'fontsize': 15})
plt.tick_params(labelsize=10)
plt.show()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Creating a barplot for 'Hours per week'
hours = data['hours-per-week'].value_counts().head(10)

plt.style.use('bmh')
plt.figure(figsize=(15, 7))
sns.barplot(hours.index, hours.values, palette='colorblind')
plt.title('Distribution of Hours of work per week', fontdict={
          'fontname': 'Monospace', 'fontsize': 20, 'fontweight': 'bold'})
plt.xlabel('Hours of work', fontdict={'fontname': 'Monospace', 'fontsize': 15})
plt.ylabel('Number of people', fontdict={
           'fontname': 'Monospace', 'fontsize': 15})
plt.show()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(36,3))
sns.countplot(x='hours-per-week', hue='salary', data=data)
plt.show()

# %%
corr = data.corr()
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(7, 5))
    ax = sns.heatmap(corr, mask=mask, vmax=.3, square=True,
                     annot=True, cmap='RdYlGn')
plt.savefig('multi2.png')
plt.show()

# %%
data['native-country'].value_counts()
# Out:
# United-States                 29753
# Mexico                          643
# Philippines                     198
# Germany                         137
# Canada                          121
# Puerto-Rico                     114
# El-Salvador                     106
# India                           100
# Cuba                             95
# England                          90
# Jamaica                          81
# South                            80
# China                            75
# Italy                            73
# Dominican-Republic               70
# Vietnam                          67
# Guatemala                        64
# Japan                            62
# Poland                           60
# Columbia                         59
# Taiwan                           51
# Haiti                            44
# Iran                             43
# Portugal                         37
# Nicaragua                        34
# Peru                             31
# France                           29
# Greece                           29
# Ecuador                          28
# Ireland                          24
# Hong                             20
# Cambodia                         19
# Trinadad&Tobago                  19
# Laos                             18
# Thailand                         18
# Yugoslavia                       16
# Outlying-US(Guam-USVI-etc)       14
# Honduras                         13
# Hungary                          13
# Scotland                         12
# Holand-Netherlands                1
# Name: native-country, dtype: int64

# %%
# Creating a countplot of income across age
plt.style.use('default')
plt.figure(figsize=(20, 7))
sns.countplot(data['age'], hue=data['salary'])
plt.title('Distribution of Income across Age', fontdict={
          'fontname': 'Monospace', 'fontsize': 20, 'fontweight': 'bold'})
plt.xlabel('Age', fontdict={'fontname': 'Monospace', 'fontsize': 15})
plt.ylabel('Number of people', fontdict={
           'fontname': 'Monospace', 'fontsize': 15})
plt.tick_params(labelsize=12)
plt.legend(loc=1, prop={'size': 15})
plt.show()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Creating a countplot of income across education
plt.style.use('seaborn')
plt.figure(figsize=(20, 7))
sns.countplot(data['education'],
              hue=data['salary'], palette='colorblind')
plt.title('Distribution of Income across Education', fontdict={
          'fontname': 'Monospace', 'fontsize': 20, 'fontweight': 'bold'})
plt.xlabel('Education', fontdict={'fontname': 'Monospace', 'fontsize': 15})
plt.ylabel('Number of people', fontdict={
           'fontname': 'Monospace', 'fontsize': 15})
plt.tick_params(labelsize=12)
plt.legend(loc=1, prop={'size': 15})
plt.show()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Creating a countplot of income across years of education
plt.style.use('bmh')
plt.figure(figsize=(20, 7))
sns.countplot(data['education-num'],
              hue=data['salary'])
plt.title('Income across Years of Education', fontdict={
          'fontname': 'Monospace', 'fontsize': 20, 'fontweight': 'bold'})
plt.xlabel('Years of Education', fontdict={
           'fontname': 'Monospace', 'fontsize': 15})
plt.ylabel('Number of people', fontdict={
           'fontname': 'Monospace', 'fontsize': 15})
plt.tick_params(labelsize=12)
plt.legend(loc=1, prop={'size': 15})
plt.savefig('bi2.png')
plt.show()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Creating a countplot of income across Marital Status
plt.style.use('seaborn')
plt.figure(figsize=(20, 7))
sns.countplot(data['marital-status'], hue=data['salary'])
plt.title('Income across Marital Status', fontdict={
          'fontname': 'Monospace', 'fontsize': 20, 'fontweight': 'bold'})
plt.xlabel('Marital Status', fontdict={
           'fontname': 'Monospace', 'fontsize': 15})
plt.ylabel('Number of people', fontdict={
           'fontname': 'Monospace', 'fontsize': 15})
plt.tick_params(labelsize=12)
plt.legend(loc=1, prop={'size': 15})
plt.show()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Creating a countplot of income across race
plt.style.use('fivethirtyeight')
plt.figure(figsize=(20, 7))
sns.countplot(data['race'], hue=data['salary'])
plt.title('Distribution of income across race', fontdict={
          'fontname': 'Monospace', 'fontsize': 20, 'fontweight': 'bold'})
plt.xlabel('Race', fontdict={
           'fontname': 'Monospace', 'fontsize': 15})
plt.ylabel('Number of people', fontdict={
           'fontname': 'Monospace', 'fontsize': 15})
plt.tick_params(labelsize=12)
plt.legend(loc=1, prop={'size': 15})
plt.show()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Creating a countplot of income across sex
plt.style.use('fivethirtyeight')
plt.figure(figsize=(7, 3))
sns.countplot(data['sex'], hue=data['salary'])
plt.title('Distribution of income across sex', fontdict={
          'fontname': 'Monospace', 'fontsize': 20, 'fontweight': 'bold'})
plt.xlabel('Sex', fontdict={
           'fontname': 'Monospace', 'fontsize': 15})
plt.ylabel('Number of people', fontdict={
           'fontname': 'Monospace', 'fontsize': 15})
plt.tick_params(labelsize=12)
plt.legend(loc=1, prop={'size': 10})
plt.savefig('bi3.png')
plt.show()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Creating a pairplot of dataset
sns.pairplot(data)
plt.savefig('multi1.png')
plt.show()

# %%
ccol=data.select_dtypes(include=["object"]).columns
ncol=data.select_dtypes(include=["int","float"]).columns

# %%
ccol
# Out:
# Index(['workclass', 'education', 'marital-status', 'occupation',
#        'relationship', 'race', 'sex', 'native-country', 'salary'],
#       dtype='object')

# %%
ncol
# Out:
# Index(['age', 'education-num', 'capital-gain', 'capital-loss',
#        'hours-per-week'],
#       dtype='object')

# %%
data['capital-gain'].nunique()
# Out:
# 119

# %%
data['hours-per-week'].nunique()
# Out:
# 94

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
data["workclass"] = le.fit_transform(data["workclass"])
data["education"] = le.fit_transform(data["education"])
data["marital-status"] = le.fit_transform(data["marital-status"])
data["occupation"] = le.fit_transform(data["occupation"])
data["relationship"] = le.fit_transform(data["relationship"])
data["race"] = le.fit_transform(data["race"])
data["sex"] = le.fit_transform(data["sex"])
data["native-country"] = le.fit_transform(data["native-country"])

# %%
data
# Out:
#        age  workclass  education  education-num  marital-status  occupation  \
# 0       39          6          9             13               4           0
# 1       50          5          9             13               2           3
# 2       38          3         11              9               0           5
# 3       53          3          1              7               2           5
# 4       28          3          9             13               2           9
# ...    ...        ...        ...            ...             ...         ...
# 32556   27          3          7             12               2          12
# 32557   40          3         11              9               2           6
# 32558   58          3         11              9               6           0
# 32559   22          3         11              9               4           0
# 32560   52          4         11              9               2           3
#
#        relationship  race  sex  capital-gain  capital-loss  hours-per-week  \
# 0                 1     4    1          2174             0              40
# 1                 0     4    1             0             0              13
# 2                 1     4    1             0             0              40
# 3                 0     2    1             0             0              40
# 4                 5     2    0             0             0              40
# ...             ...   ...  ...           ...           ...             ...
# 32556             5     4    0             0             0              38
# 32557             0     4    1             0             0              40
# 32558             4     4    0             0             0              40
# 32559             3     4    1             0             0              20
# 32560             5     4    0         15024             0              40
#
#        native-country salary
# 0                  38  <=50K
# 1                  38  <=50K
# 2                  38  <=50K
# 3                  38  <=50K
# 4                   4  <=50K
# ...               ...    ...
# 32556              38  <=50K
# 32557              38   >50K
# 32558              38  <=50K
# 32559              38  <=50K
# 32560              38   >50K
#
# [32561 rows x 14 columns]

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'education', 'education-num', 'marital-status',
#        'occupation', 'relationship', 'race', 'sex', 'capital-gain',
#        'capital-loss', 'hours-per-week', 'native-country', 'salary'],
#       dtype='object')

# %%
data.head(50)
# Out:
#     age  workclass  education  education-num  marital-status  occupation  \
# 0    39          6          9             13               4           0
# 1    50          5          9             13               2           3
# 2    38          3         11              9               0           5
# 3    53          3          1              7               2           5
# 4    28          3          9             13               2           9
# 5    37          3         12             14               2           3
# 6    49          3          6              5               3           7
# 7    52          5         11              9               2           3
# 8    31          3         12             14               4           9
# 9    42          3          9             13               2           3
# 10   37          3         15             10               2           3
# 11   30          6          9             13               2           9
# 12   23          3          9             13               4           0
# 13   32          3          7             12               4          11
# 14   40          3          8             11               2           2
# 15   34          3          5              4               2          13
# 16   25          5         11              9               4           4
# 17   32          3         11              9               4           6
# 18   38          3          1              7               2          11
# 19   43          5         12             14               0           3
# 20   40          3         10             16               2           9
# 21   54          3         11              9               5           7
# 22   35          0          6              5               2           4
# 23   43          3          1              7               2          13
# 24   59          3         11              9               0          12
# 25   56          1          9             13               2          12
# 26   19          3         11              9               4           2
# 27   54          3         15             10               2           9
# 28   39          3         11              9               0           3
# 29   49          3         11              9               2           2
# 30   23          1          7             12               4          10
# 31   20          3         15             10               4          11
# 32   45          3          9             13               0           3
# 33   30          0         15             10               2           0
# 34   22          6         15             10               2           7
# 35   48          3          1              7               4           6
# 36   21          3         15             10               4           6
# 37   19          3         11              9               1           0
# 38   31          3         15             10               2          11
# 39   48          5          7             12               2           9
# 40   31          3          6              5               2           6
# 41   53          5          9             13               2           9
# 42   24          3          9             13               2          12
# 43   49          3         11              9               5           0
# 44   25          3         11              9               4           5
# 45   57          0          9             13               2           9
# 46   53          3         11              9               2           6
# 47   44          3         12             14               0           3
# 48   41          6          8             11               2           2
# 49   29          3          8             11               4           9
#
#     relationship  race  sex  capital-gain  capital-loss  hours-per-week  \
# 0              1     4    1          2174             0              40
# 1              0     4    1             0             0              13
# 2              1     4    1             0             0              40
# 3              0     2    1             0             0              40
# 4              5     2    0             0             0              40
# 5              5     4    0             0             0              40
# 6              1     2    0             0             0              16
# 7              0     4    1             0             0              45
# 8              1     4    0         14084             0              50
# 9              0     4    1          5178             0              40
# 10             0     2    1             0             0              80
# 11             0     1    1             0             0              40
# 12             3     4    0             0             0              30
# 13             1     2    1             0             0              50
# 14             0     1    1             0             0              40
# 15             0     0    1             0             0              45
# 16             3     4    1             0             0              35
# 17             4     4    1             0             0              40
# 18             0     4    1             0             0              50
# 19             4     4    0             0             0              45
# 20             0     4    1             0             0              60
# 21             4     2    0             0             0              20
# 22             0     2    1             0             0              40
# 23             0     4    1             0          2042              40
# 24             4     4    0             0             0              40
# 25             0     4    1             0             0              40
# 26             3     4    1             0             0              40
# 27             0     1    1             0             0              60
# 28             1     4    1             0             0              80
# 29             0     4    1             0             0              40
# 30             1     4    1             0             0              52
# 31             3     2    1             0             0              44
# 32             3     4    1             0          1408              40
# 33             3     4    1             0             0              40
# 34             0     2    1             0             0              15
# 35             4     4    1             0             0              40
# 36             3     4    1             0             0              40
# 37             5     4    0             0             0              25
# 38             0     4    1             0             0              38
# 39             0     4    1             0             0              40
# 40             0     4    1             0             0              43
# 41             0     4    1             0             0              40
# 42             0     4    1             0             0              50
# 43             4     4    0             0             0              40
# 44             1     4    1             0             0              35
# 45             0     2    1             0             0              40
# 46             0     4    1             0             0              38
# 47             4     4    0             0             0              40
# 48             0     4    1             0             0              40
# 49             1     4    1             0             0              43
#
#     native-country salary
# 0               38  <=50K
# 1               38  <=50K
# 2               38  <=50K
# 3               38  <=50K
# 4                4  <=50K
# 5               38  <=50K
# 6               22  <=50K
# 7               38   >50K
# 8               38   >50K
# 9               38   >50K
# 10              38   >50K
# 11              18   >50K
# 12              38  <=50K
# 13              38  <=50K
# 14              38   >50K
# 15              25  <=50K
# 16              38  <=50K
# 17              38  <=50K
# 18              38  <=50K
# 19              38   >50K
# 20              38   >50K
# 21              38  <=50K
# 22              38  <=50K
# 23              38  <=50K
# 24              38  <=50K
# 25              38   >50K
# 26              38  <=50K
# 27              34   >50K
# 28              38  <=50K
# 29              38  <=50K
# 30              38  <=50K
# 31              38  <=50K
# 32              38  <=50K
# 33              38  <=50K
# 34              38  <=50K
# 35              32  <=50K
# 36              38  <=50K
# 37              38  <=50K
# 38              38   >50K
# 39              38  <=50K
# 40              38  <=50K
# 41              38  <=50K
# 42              38  <=50K
# 43              38  <=50K
# 44              38  <=50K
# 45              38   >50K
# 46              38  <=50K
# 32549             2     4    0             0             0              40
# 32550             0     4    1             0             0              50
# 32551             0     0    1             0             0              40
# 32552             0     4    1             0             0              45
# 32553             1     1    1             0             0              11
# 32554             0     4    1             0             0              40
# 32555             1     4    1             0             0              40
# 32556             5     4    0             0             0              38
# 32557             0     4    1             0             0              40
# 32558             4     4    0             0             0              40
# 32559             3     4    1             0             0              20
# 32560             5     4    0         15024             0              40
#
#        native-country salary
# 32511              38  <=50K
# 32512              38  <=50K
# 32513              38   >50K
# 32514              38  <=50K
# 32515              38  <=50K
# 32516              38  <=50K
# 32517              38  <=50K
# 32518              38   >50K
# 32519              38   >50K
# 32520              38  <=50K
# 32521              38  <=50K
# 32522              38  <=50K
# 32523              38  <=50K
# 32524              38  <=50K
# 32525              38  <=50K
# 32526              38  <=50K
# 32527              38  <=50K
# 32528              38  <=50K
# 32529              38  <=50K
# 32530              38   >50K
# 32531              38  <=50K
# 32532              38   >50K
# 32533              23   >50K
# 32534              38  <=50K
# 32535              38  <=50K
# 32536              38   >50K
# 32537              38  <=50K
# 32538              38   >50K
# 32539              38   >50K
# 32540              38  <=50K
# 32541              38  <=50K
# 32542              38  <=50K
# 32543              38  <=50K
# 32544              38  <=50K
# 32545              38   >50K
# 32546              38  <=50K
# 32547              25  <=50K
# 32548              38  <=50K
# 32549              38  <=50K
# 32550              38  <=50K
# 32551              38  <=50K
# 32552              38  <=50K
# 32553              35  <=50K
# 32554              38   >50K
# 32555              38  <=50K
# 32556              38  <=50K
# 32557              38   >50K
# 32558              38  <=50K
# 32559              38  <=50K
# 32560              38   >50K

# %%
from sklearn.preprocessing import StandardScaler

# %%
data1=data.drop(['capital-gain','capital-loss', 'hours-per-week','age'],axis=1)

# %%
data1
# Out:
#        workclass  education  education-num  marital-status  occupation  \
# 0              6          9             13               4           0
# 1              5          9             13               2           3
# 2              3         11              9               0           5
# 3              3          1              7               2           5
# 4              3          9             13               2           9
# ...          ...        ...            ...             ...         ...
# 32556          3          7             12               2          12
# 32557          3         11              9               2           6
# 32558          3         11              9               6           0
# 32559          3         11              9               4           0
# 32560          4         11              9               2           3
#
#        relationship  race  sex  native-country salary
# 0                 1     4    1              38  <=50K
# 1                 0     4    1              38  <=50K
# 2                 1     4    1              38  <=50K
# 3                 0     2    1              38  <=50K
# 4                 5     2    0               4  <=50K
# ...             ...   ...  ...             ...    ...
# 32556             5     4    0              38  <=50K
# 32557             0     4    1              38   >50K
# 32558             4     4    0              38  <=50K
# 32559             3     4    1              38  <=50K
# 32560             5     4    0              38   >50K
#
# [32561 rows x 10 columns]

# %%
data2=data[['capital-gain','capital-loss', 'hours-per-week','age']]

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss=StandardScaler()
data2=ss.fit_transform(data2)
data2=pd.DataFrame(data2,columns=['capital-gain','capital-loss', 'hours-per-week','age'])
data2.head()
# Out:
#    capital-gain  capital-loss  hours-per-week       age
# 0      0.148453      -0.21666       -0.035429  0.030671
# 1     -0.145920      -0.21666       -2.222153  0.837109
# 2     -0.145920      -0.21666       -0.035429 -0.042642
# 3     -0.145920      -0.21666       -0.035429  1.057047
# 4     -0.145920      -0.21666       -0.035429 -0.775768

# %%
data2
# Out:
#        capital-gain  capital-loss  hours-per-week       age
# 0          0.148453      -0.21666       -0.035429  0.030671
# 1         -0.145920      -0.21666       -2.222153  0.837109
# 2         -0.145920      -0.21666       -0.035429 -0.042642
# 3         -0.145920      -0.21666       -0.035429  1.057047
# 4         -0.145920      -0.21666       -0.035429 -0.775768
# ...             ...           ...             ...       ...
# 32556     -0.145920      -0.21666       -0.197409 -0.849080
# 32557     -0.145920      -0.21666       -0.035429  0.103983
# 32558     -0.145920      -0.21666       -0.035429  1.423610
# 32559     -0.145920      -0.21666       -1.655225 -1.215643
# 32560      1.888424      -0.21666       -0.035429  0.983734
#
# [32561 rows x 4 columns]

# %%
data2
# Out:
#        capital-gain  capital-loss  hours-per-week       age
# 0          0.148453      -0.21666       -0.035429  0.030671
# 1         -0.145920      -0.21666       -2.222153  0.837109
# 2         -0.145920      -0.21666       -0.035429 -0.042642
# 3         -0.145920      -0.21666       -0.035429  1.057047
# 4         -0.145920      -0.21666       -0.035429 -0.775768
# ...             ...           ...             ...       ...
# 32556     -0.145920      -0.21666       -0.197409 -0.849080
# 32557     -0.145920      -0.21666       -0.035429  0.103983
# 32558     -0.145920      -0.21666       -0.035429  1.423610
# 32559     -0.145920      -0.21666       -1.655225 -1.215643
# 32560      1.888424      -0.21666       -0.035429  0.983734
#
# [32561 rows x 4 columns]

# %%
frame1=[data2,data1]
data3=pd.concat(frame1,axis=1)

# %%
data3
# Out:
#        capital-gain  capital-loss  hours-per-week       age  workclass  \
# 0          0.148453      -0.21666       -0.035429  0.030671          6
# 1         -0.145920      -0.21666       -2.222153  0.837109          5
# 2         -0.145920      -0.21666       -0.035429 -0.042642          3
# 3         -0.145920      -0.21666       -0.035429  1.057047          3
# 4         -0.145920      -0.21666       -0.035429 -0.775768          3
# ...             ...           ...             ...       ...        ...
# 32556     -0.145920      -0.21666       -0.197409 -0.849080          3
# 32557     -0.145920      -0.21666       -0.035429  0.103983          3
# 32558     -0.145920      -0.21666       -0.035429  1.423610          3
# 32559     -0.145920      -0.21666       -1.655225 -1.215643          3
# 32560      1.888424      -0.21666       -0.035429  0.983734          4
#
#        education  education-num  marital-status  occupation  relationship  \
# 0              9             13               4           0             1
# 1              9             13               2           3             0
# 2             11              9               0           5             1
# 3              1              7               2           5             0
# 4              9             13               2           9             5
# ...          ...            ...             ...         ...           ...
# 32556          7             12               2          12             5
# 32557         11              9               2           6             0
# 32558         11              9               6           0             4
# 32559         11              9               4           0             3
# 32560         11              9               2           3             5
#
#        race  sex  native-country salary
# 0         4    1              38  <=50K
# 1         4    1              38  <=50K
# 2         4    1              38  <=50K
# 3         2    1              38  <=50K
# 4         2    0               4  <=50K
# ...     ...  ...             ...    ...
# 32556     4    0              38  <=50K
# 32557     4    1              38   >50K
# 32558     4    0              38  <=50K
# 32559     4    1              38  <=50K
# 32560     4    0              38   >50K
#
# [32561 rows x 14 columns]

# %%
data3.columns
# Out:
# Index(['capital-gain', 'capital-loss', 'hours-per-week', 'age', 'workclass',
#        'education', 'education-num', 'marital-status', 'occupation',
#        'relationship', 'race', 'sex', 'native-country', 'salary'],
#       dtype='object')

# %%
data3.to_csv('preprocessing_hr_tcs.csv')
